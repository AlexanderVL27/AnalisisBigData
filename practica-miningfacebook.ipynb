# %%
import pandas as pd

df = pd.read_json("../input/datadeface/your_posts_1.json")

df.head
# Out:
# <bound method NDFrame.head of                timestamp                                        attachments  \
# 0    2013-11-28 00:04:25  [{'data': [{'external_context': {'name': 'Halo...
# 1    2013-11-28 00:04:25  [{'data': [{'external_context': {'name': 'Awak...
# 2    2013-12-13 22:19:04                                                NaN
# 3    2013-12-13 22:19:09                                                NaN
# 4    2013-12-13 22:19:14                                                NaN
# ...                  ...                                                ...
# 1105 2022-10-14 17:40:22                                                 []
# 1106 2022-10-20 18:16:23                                                 []
# 1107 2022-10-22 00:37:13                                                 []
# 1108 2022-11-01 02:22:18                                                 []
# 1109 2022-11-04 02:07:23                                                 []
#
#                                                    data  \
# 0                                                    []
# 1                                                    []
# 2                                                    []
# 3                                                    []
# 4                                                    []
# ...                                                 ...
# 1105                 [{'update_timestamp': 1665769222}]
# 1106  [{'post': 'SalÃ­ en la portadaaaaa'}, {'update...
# 1107  [{'post': 'Grande PROgramadores'}, {'update_ti...
# 1108                 [{'update_timestamp': 1667269338}]
# 1109                 [{'update_timestamp': 1667527643}]
#
#                                                   title tags
# 0     Alexander Villalobos agregÃ³ Halo: Cryptum a l...  NaN
# 1     Alexander Villalobos agregÃ³ Awakening: The Ar...  NaN
# 2           Alexander Villalobos  recomienda La granja.  NaN
# 3       Alexander Villalobos  recomienda Goku el mejor.  NaN
# 4     Alexander Villalobos  recomienda A que Dragon ...  NaN
# ...                                                 ...  ...
# 1105                                                NaN  NaN
# 1106                                                NaN  NaN
# 1107                                                NaN  NaN
# 1108                                                NaN  NaN
# 1109                                                NaN  NaN
#
# [1110 rows x 5 columns]>

# %%
df.rename(columns = {'timestamp':'date'},inplace=True)

df= df.drop(['attachments','title','tags'],axis = 1)

df.info()

df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1110 entries, 0 to 1109
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1110 non-null   datetime64[ns]
#  1   data    1110 non-null   object
# dtypes: datetime64[ns](1), object(1)
# memory usage: 17.5+ KB
#                  date data
# 0 2013-11-28 00:04:25   []
# 1 2013-11-28 00:04:25   []
# 2 2013-12-13 22:19:04   []
# 3 2013-12-13 22:19:09   []
# 4 2013-12-13 22:19:14   []

# %%
print(df.shape)
#df.head()
df.tail()
# Out:
# (1110, 2)
#                     date                                               data
# 1105 2022-10-14 17:40:22                 [{'update_timestamp': 1665769222}]
# 1106 2022-10-20 18:16:23  [{'post': 'SalÃ­ en la portadaaaaa'}, {'update...
# 1107 2022-10-22 00:37:13  [{'post': 'Grande PROgramadores'}, {'update_ti...
# 1108 2022-11-01 02:22:18                 [{'update_timestamp': 1667269338}]
# 1109 2022-11-04 02:07:23                 [{'update_timestamp': 1667527643}]

# %%
df = df.set_index('date')
post_counts=df['data'].resample('MS').size()
post_counts.head(200)
# Out:
# date
# 2013-11-01     2
# 2013-12-01     9
# 2014-01-01     0
# 2014-02-01     0
# 2014-03-01     0
#               ..
# 2022-07-01    57
# 2022-08-01    31
# 2022-09-01     4
# 2022-10-01     5
# 2022-11-01     2
# Freq: MS, Name: data, Length: 109, dtype: int64

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
sns.set(rc={'figure.figsize':(40,20)})
sns.set(font_scale=3)

x_labels = post_counts.index

sns.barplot(x_labels, post_counts, color = "blue")

tick_positions = np.arange(10, len(x_labels),step = 24)

plt.xticks(tick_positions, x_labels[tick_positions].strftime("%Y"))

plt.show();
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
import pandas as pd

df = pd.read_json("../input/postyuri/your_posts_0.json")

df.head
# Out:
# <bound method NDFrame.head of               timestamp                                               data  \
# 0   2013-02-08 19:32:07  [{'post': 'Oli soy nueva te invito a qe seas m...
# 1   2013-02-08 19:56:22  [{'post': 'Apoco no es una ternura esta perrit...
# 2   2013-02-09 21:51:30                          [{'post': 'en facebook'}]
# 3   2013-02-28 03:15:20      [{'post': 'Viendo una bola de fuego grande'}]
# 4   2013-03-09 02:10:43                     [{'post': 'Adoro
# a mi bff:)'}]
# ..                  ...                                                ...
# 287 2021-02-28 21:40:35                                 [{'post': 'â¨.'}]
# 288 2021-05-26 14:37:37  [{'post': 'Hello hello, feliz dÃ­a espero te l...
# 289 2021-06-08 19:12:14                 [{'update_timestamp': 1623179534}]
# 290 2021-07-19 02:53:24                                 [{'post': 'â¨.'}]
# 291 2022-10-31 01:43:45                                  [{'post': 'â¨'}]
#
#                                                  title  \
# 0                   Yajaira Ruiz actualizÃ³ su estado.
# 1                 Yajaira Ruiz agregÃ³ una foto nueva.
# 2                   Yajaira Ruiz actualizÃ³ su estado.
# 3                   Yajaira Ruiz actualizÃ³ su estado.
# 4                   Yajaira Ruiz actualizÃ³ su estado.
# ..                                                 ...
# 287                                                NaN
# 288  Yajaira Ruiz escribiÃ³ en la biografÃ­a de Zil...
# 289                                                NaN
# 290                                                NaN
# 291                                                NaN
#
#                                            attachments tags
# 0                                                  NaN  NaN
# 1    [{'data': [{'media': {'uri': 'posts/media/Foto...  NaN
# 2                                                  NaN  NaN
# 3                                                  NaN  NaN
# 4                                                  NaN  NaN
# ..                                                 ...  ...
# 287  [{'data': [{'media': {'uri': 'posts/media/Foto...  NaN
# 288                                                NaN  NaN
# 289                                                 []  NaN
# 290  [{'data': [{'media': {'uri': 'posts/media/Foto...  NaN
# 291  [{'data': [{'media': {'uri': 'posts/media/Foto...  NaN
#
# [292 rows x 5 columns]>

# %%
df.rename(columns = {'timestamp':'date'},inplace=True)

df= df.drop(['attachments','title','tags'],axis = 1)

df.info()

df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 292 entries, 0 to 291
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    292 non-null    datetime64[ns]
#  1   data    292 non-null    object
# dtypes: datetime64[ns](1), object(1)
# memory usage: 4.7+ KB
#                  date                                               data
# 0 2013-02-08 19:32:07  [{'post': 'Oli soy nueva te invito a qe seas m...
# 1 2013-02-08 19:56:22  [{'post': 'Apoco no es una ternura esta perrit...
# 2 2013-02-09 21:51:30                          [{'post': 'en facebook'}]
# 3 2013-02-28 03:15:20      [{'post': 'Viendo una bola de fuego grande'}]
# 4 2013-03-09 02:10:43                     [{'post': 'Adoro
# a mi bff:)'}]

# %%
print(df.shape)
#df.head()
df.tail()
# Out:
# (292, 2)
#                    date                                               data
# 287 2021-02-28 21:40:35                                 [{'post': 'â¨.'}]
# 288 2021-05-26 14:37:37  [{'post': 'Hello hello, feliz dÃ­a espero te l...
# 289 2021-06-08 19:12:14                 [{'update_timestamp': 1623179534}]
# 290 2021-07-19 02:53:24                                 [{'post': 'â¨.'}]
# 291 2022-10-31 01:43:45                                  [{'post': 'â¨'}]

# %%
df = df.set_index('date')
post_counts=df['data'].resample('MS').size()
post_counts.head(200)
# Out:
# date
# 2013-02-01     4
# 2013-03-01    10
# 2013-04-01     6
# 2013-05-01     0
# 2013-06-01     3
#               ..
# 2022-06-01     0
# 2022-07-01     0
# 2022-08-01     0
# 2022-09-01     0
# 2022-10-01     1
# Freq: MS, Name: data, Length: 117, dtype: int64

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
sns.set(rc={'figure.figsize':(40,20)})
sns.set(font_scale=3)

x_labels = post_counts.index

sns.barplot(x_labels, post_counts, color = "blue")

tick_positions = np.arange(10, len(x_labels),step = 24)

plt.xticks(tick_positions, x_labels[tick_positions].strftime("%Y"))

plt.show();
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
import json
from datetime import datetime
import pandas as pd

# %%
with open('../input/datadeface/your_posts_1.json') as f:
    data = json.load(f)

# %%
print (data)
# Out:
# [{'timestamp': 1385597065, 'attachments': [{'data': [{'external_context': {'name': 'Halo: Cryptum'}}]}], 'data': [], 'title': 'Alexander Villalobos agregÃ³ Halo: Cryptum a libros que leyÃ³.'}, {'timestamp': 1385597065, 'attachments': [{'data': [{'external_context': {'name': 'Awakening: The Art of Halo 4'}}]}], 'data': [], 'title': 'Alexander Villalobos agregÃ³ Awakening: The Art of Halo 4 a libros que leyÃ³.'}, {'timestamp': 1386973144, 'data': [], 'title': 'Alexander Villalobos  recomienda La granja.'}, {'timestamp': 1386973149, 'data': [], 'title': 'Alexander Villalobos  recomienda Goku el mejor.'}, {'timestamp': 1386973154, 'data': [], 'title': 'Alexander Villalobos  recomienda A que Dragon ball z  es el mejor anime.'}, {'timestamp': 1386973274, 'data': [], 'title': 'Alexander Villalobos  recomienda Lab Rats.'}, {'timestamp': 1386973277, 'data': [], 'title': 'Alexander Villalobos  recomienda No Molestar.'}, {'timestamp': 1386973281, 'data': [], 'title': 'Alexander Villalobos  recomienda Galaxia anime ã\x83\x84.'}, {'timestamp': 1386973283, 'data': [], 'title': 'Alexander Villalobos  recomienda Hora de Aventuras.'}, {'timestamp': 1386973286, 'data': [], 'title': 'Alexander Villalobos  recomienda Hora de Aventura.'}, {'timestamp': 1388440694, 'attachments': [{'data': [{'external_context': {'name': 'Gears of War: Anvil Gate'}}]}], 'data': [], 'title': 'Alexander Villalobos agregÃ³ Gears of War: Anvil Gate a libros que leyÃ³.'}, {'timestamp': 1447801536, 'data': [{'post': 'FELICIDADES XP'}], 'title': 'Alexander Villalobos escribiÃ³ en la biografÃ\xada de Jaime ZermeÃ±o.'}, {'timestamp': 1448487409, 'data': [{'post': 'FELICIDADES Â¡Â¡Â¡Â¡Â¡Â¡Â¡Â¡Â¡Â¡Â¡Â¡Â¡Â¡Â¡'}], 'title': 'Alexander Villalobos escribiÃ³ en la biografÃ\xada de Axel Mendo.'}, {'timestamp': 1452961716, 'data': [{'post': '!FELIZIDADESÂ¡ QUE TE LA PASES MUY BIEN EN ESTE DIA :v xp'}], 'title': 'Alexander Villalobos escribiÃ³ en la biografÃ\xada de Alondra Trejo.'}, {'timestamp': 1461187269, 'data': [], 'title': 'Alexander Villalobos actualizÃ³ su estado.'}, {'timestamp': 1465847033, 'attachments': [{'data': [{'external_context': {'url': 'http://imagehost7.online-image-editor.com/oie_upload/images/13212520wCqXI/TQb91C5luB4X.gif'}}]}], 'data': [{'post': ':v'}, {'update_timestamp': 1465847033}]}, {'timestamp': 1470500575, 'data': [{'post': ":'v"}], 'title': 'Alexander Villalobos actualizÃ³ su estado.'}, {'timestamp': 1472493581, 'data': [], 'title': 'Alexander Villalobos actualizÃ³ su estado.'}, {'timestamp': 1472527724, 'data': [], 'title': 'Alexander Villalobos actualizÃ³ su estado.'}, {'timestamp': 1472745111, 'data': [], 'title': 'Alexander Villalobos actualizÃ³ su estado.'}, {'timestamp': 1473046117, 'data': [], 'title': 'Alexander Villalobos actualizÃ³ su estado.'}, {'timestamp': 1476066236, 'attachments': [], 'data': [{'update_timestamp': 1476066236}]}, {'timestamp': 1476575631, 'data': [], 'title': 'Alexander Villalobos actualizÃ³ su estado.'}, {'timestamp': 1476755646, 'data': [], 'title': 'Alexander Villalobos actualizÃ³ su estado.'}, {'timestamp': 1479183494, 'data': [], 'title': 'Alexander Villalobos actualizÃ³ su estado.'}, {'timestamp': 1480020497, 'data': [], 'title': 'Alexander Villalobos actualizÃ³ su estado.'}, {'timestamp': 1480020572, 'data': [], 'title': 'Alexander Villalobos actualizÃ³ su estado.'}, {'timestamp': 1480086781, 'data': [], 'title': 'Alexander Villalobos actualizÃ³ su estado.'}, {'timestamp': 1481206093, 'data': [], 'title': 'Alexander Villalobos actualizÃ³ su estado.'}, {'timestamp': 1481247508, 'data': [], 'title': 'Alexander Villalobos actualizÃ³ su estado.'}, {'timestamp': 1481592943, 'attachments': [{'data': [{'media': {'uri': 'posts/media/videos/15507290_157283834752116_3155963126109700096_n_709550112555331.mp4', 'creation_timestamp': 1481592943, 'media_metadata': {'video_metadata': {'exif_data': [{'upload_ip': '2401:db00:11:6012:face:0:15:0', 'upload_timestamp': 0}]}}, 'thumbnail': {'uri': 'https://interncache-atn.fbcdn.net/v/t1 ...

# %%
#formato de data
print(type(data))
# Out:
# <class 'list'>

# %%
print(data[1000])
list(data[1000])
# Out:
# {'timestamp': 1656372754, 'attachments': [], 'data': [{'update_timestamp': 1656372754}]}
# ['timestamp', 'attachments', 'data']
