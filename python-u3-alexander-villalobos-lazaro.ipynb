# %%
import random
import numpy as np
def listaAleatorios(n):
    lista = [0]  * 10
    for i in range(10):
        lista[i] = random.randint(0, 10)
        return lista
aleatorios=listaAleatorios(10)
print(aleatorios)
print("*************************************")
print("Numero aleatorio del arreglo")
num_random = random.randint(0, 9)
print(num_random)
print("*************************************")
print("Valor de la posicion")
aleatorios[num_random]
# Out:
# [7, 0, 0, 0, 0, 0, 0, 0, 0, 0]
# *************************************
# Numero aleatorio del arreglo
# 7
# *************************************
# Valor de la posicion
# 0
